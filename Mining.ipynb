# %%
#find files
import pandas as pd
import glob

de = True
eng = False

files = glob.glob(r"C:\Users\julia\Documents\Eigene Dokumente\Studium\4Semester\Workshop_Mining_Software_Repositories\Projekt D Skilltree\Datensammlung\Bundesagentur für Arbeit\Deutsch\*.txt")
files += glob.glob(r"C:\Users\julia\Documents\Eigene Dokumente\Studium\4Semester\Workshop_Mining_Software_Repositories\Projekt D Skilltree\Datensammlung\XING\Deutsch\*.txt")
print(len(files))

startdfs = [0 for x in range(len(files))]

#import txt files as dataframes
for i in range(len(files)):
    df= pd.read_csv(files[i], delimiter = "\t", header = None)
    startdfs[i]=df
print(startdfs)
    

#create a more sorted df
index = []
lang_dict = {}
job_dict = {}
company_dict = {}
descr_dict = {}

for j in range(len(startdfs)):
    
    df = startdfs[j]
    index += [j]
    
    if de:
        lang ="de"
    elif en:
        lang= "en"
    lang_dict[j]= lang;
    
    job = df.iloc[0,0]
    job_dict[j]= job
    
    company = df.iloc[1,0]
    company_dict[j]= company;
    
    descr = df.iloc[2,0]
    for i in range(3,len(df.index)):
        descr = descr + " "+ df.iloc[i,0].strip("◾")
    descr_dict[j] = descr
    
lang_series = pd.Series(lang_dict)
job_series = pd.Series(job_dict)
company_series = pd.Series(company_dict)
descr_series = pd.Series(descr_dict)

df = pd.DataFrame({'job':job_series, 'company':company_series, 'description':descr_series, 'language':lang_series,})
print(df)

#let the spacy magic begin ^^
import spacy
from spacy.tokens import Doc
from spacy.lang.de import German

nlp = spacy.load("de_core_news_sm")

#fill doc with job descriptions
desstr = ""
for i in range(len(df)):
    desstr =desstr +" "+ df.iloc[i,2]
doc = nlp(desstr)
nouns = {}
pnouns = {}
for token in doc:
    if token.pos_ == "NOUN":
        if token.text in nouns:
            nouns[token.text] = nouns[token.text]+1
        else:
            nouns[token.text] = 1
    elif token.pos_ =="PROPN":
        if token.text in pnouns:
            pnouns[token.text] = pnouns[token.text]+1
        else:
            pnouns[token.text] = 1
noun_series = pd.Series(nouns)
pnoun_series = pd.Series(pnouns)
series = noun_series.append(pnoun_series)

df2 =pd.DataFrame({'count':series})
df3 = (df2.loc[df2['count'] >= 10])
df3.to_csv(r"C:\Users\julia\Documents\Eigene Dokumente\Studium\4Semester\Workshop_Mining_Software_Repositories\Projekt D Skilltree\count3.csv", sep = ";", decimal = ",", encoding ="UTF-8")
# Out:
# 33
# [                                                    0
# 0                                Data Analyst (w/m/d)
# 1                         Brunel GmbH NL Braunschweig
# 2                                 Stellenbeschreibung
# 3   Möchten Sie die nächste Stufe in Ihrer Karrier...
# 4                                Arbeitsbeschreibung:
# 5   - In Zusammenarbeit mit Kollegen pflegen Sie D...
# 6   - Innerhalb des Accounting & Controlling Teams...
# 7   - Sie arbeiten aktiv in Projekten zur Bereitst...
# 8   - Innerhalb des Projekts stimmen Sie die Anfor...
# 9   - Abgerundet wird Ihr Tätigkeitsumfang durch d...
# 10                                        Ihr Profil:
# 11  - Erfolgreich abgeschlossenes Studium der (Wir...
# 12  - Gute Kenntnisse in SQL-Datenbanken, sowie im...
# 13  - Prozesskenntnisse und Projekterfahrung, sowi...
# 14  - Fließende Deutsch- und gute Englischkenntnis...
# 15                                        Wir bieten:
# 16  Wir bieten Ihnen eine Unternehmenskultur, die ...
# 17                                       Über Brunel:
# 18  Arbeiten bei Brunel bedeutet: Attraktive Arbei...,                                                     0
# 0                          Data Analyst Visualisation
# 1             direct services Gütersloh GmbH – BPG IT
# 2                          Data Analyst Visualisation
# 3   Die BPG-IT gehört zur Bertelsmann Printing Gro...
# 4                                            Aufgaben
# 5   Du liebst die tägliche Arbeit mit Daten und ha...
# 6   Für unser DevOps-Team in Gütersloh suchen wir ...
# 7                                     Deine Aufgaben:
# 8   Du entwickelst das Analytics-System hinsichtli...
# 9   Du erhebst fachliche sowie technische Anforder...
# 10  Mit unserem Team konzipierst und entwickelst D...
# 11  Du wirkst aktiv dabei mit, datengetriebene Ges...
# 12                                             Profil
# 13  Du teilst mit uns die Leidenschaft für Daten u...
# 14  Du liebst die Herausforderung, dem Nutzer des ...
# 15  Du begeisterst Dich für neue Technologien und ...
# 16  Du bist kreativ, handelst eigenverantwortlich,...
# 17  Komplexe Sachverhalte kannst Du schnell erfass...
# 18  Du verfügst über Erfahrung mit Analytics-Syste...
# 19                                         Wir bieten
# 20  Du bist Teil eines ambitionierten und kollegia...
# 21  Ein persönlicher Coach sorgt für eine schnelle...
# 22  Unsere offene Unternehmens- und Team-Kultur gi...
# 23  Regelmäßige Leistungs- und Entwicklungsgespräc...
# 24  Ein umfangreiches Gesundheits- und Fitnessprog...
# 25  Die Gewinn- und Erfolgsbeteiligung, vermögensw...
# 26  In der Bertelsmann Printing Group sind die Dru...,                                                     0
# 0                               Data Engineer (m/w/d)
# 1                                     alexander thamm
# 2      Festanstellung, Vollzeit · an allen Standorten
# 3                                          STARTDATUM
# 4                          Wir suchen dich ab sofort.
# 5   Die Position ist an den Standorten Berlin, Lei...
# 6                                      DEINE AUFGABEN
# 7   Deine Aufgaben als Data Engineer bei [at] sind...
# 8   Entwerfe, entwickle, teste, debugge, automatis...
# 9   Wähle die Technologien für die Implementierung...
# 10  Entwickle Datenpipelines auf Basis von Cluster...
# 11         Visualisiere Daten für verschiedene Zwecke
# 12  Bewerte die Datenqualität und führe wenn nötig...
# 13                                        DEIN PROFIL
# 14  Als Data Engineer bei [at] solltest du folgend...
# 15  Erfolgreich abgeschlossenes Studium der Inform...
# 16  Mind. 2 Jahre Berufserfahrung als Software Eng...
# 17  Sehr gute Kenntnisse der Programmiersprachen P...
# 18  Kenntnisse im Bereich der Cloud Technologien z...
# 19  Kenntnisse und Erfahrung im Umgang mit Hadoop-...
# 20  Reisebereitschaft im Rahmen einer Consulting T...
# 21  Idealerweise flüssige Deutsch- und Englischken...
# 22                                         WIR BIETEN
# 23  DATA bewegt uns! Was dich auf deiner persönlic...
# 24    Stark wachsendes Unternehmen mit Start-Up-Flair
# 25  Direkte Kommunikationswege, flache Hierarchien...
# 26  Starte deinen neuen Job mit einem unbefristete...
# 27  Vielfältige Weiterbildungsmöglichkeiten innerh...
# 28  Hab Spaß bei zahlreichen gemeinsamen Events & ...
# 29        Exklusive Rabatte von ausgewählten Partnern
# 30          Halte dich fit mit unseren Sportangeboten
# 31                          Ein Office in bester Lage,                                                     0
# 0                      Data Engineer (m/w/d) 154-6139
# 1                                   top itservices AG
# 2                                 Stellenbeschreibung
# 3   Sie suchen einen Arbeitgeber, der Ihre Experti...
# 4   Nehmen Sie die Herausforderung an und besetzen...
# 5                                       Ihre Aufgaben
# 6   ◾ Durchführung der wissenschaftlichen Projektk...
# 7   ◾Implementierung (sero-) epidemiologischer Stu...
# 8   ◾Prozessanalyse im Rahmen der epidemiologische...
# 9   ◾Vorgabenorientierte Prozessübertragung für di...
# 10  ◾Gestaltung von Inhalten der Softwareentwicklu...
# 11       ◾Lehrtätigkeit im PhD Programm Epidemiologie
# 12  ◾Selbstständige wissenschaftliche Analyse und ...
# 13  ◾Erstellung von Drittmittelanträgen und Projek...
# 14                           Erforderliche Kenntnisse
# 15  ◾ Abgeschlossenes Hochschulstudium der Medizin...
# 16  ◾Promotion oder thematisch orientierte Publika...
# 17  ◾Mindestens 5 Jahre Berufserfahrung im Bereich...
# 18  ◾Projekterfahrung in der öffentlichen Gesundhe...
# 19  ◾Know-how im Bereich der Virtualisierung (z.B....
# 20  ◾Praktische Kenntnisse in der Konzeption und D...
# 21  ◾Verhandlungssichere Deutschkenntnisse in Wort...
# 22                               Was wir Ihnen bieten
# 23  ◾ Transparenter und schneller Bewerbungsprozes...
# 24  ◾Vertrauensvolle & persönliche Begleitung zu j...
# 25  ◾Einsatz bei unserem Kundenunternehmen der Ges...
# 26     ◾100% Remote Work: ortsungebunden und flexibel
# 27  ◾Individuelle Beratung und bedarfsgerechte Ver...,                                                     0
# 0                                      Data Scientist
# 1                                            Bayer AG
# 2                                 Stellenbeschreibung
# 3   Bayer ist ein weltweit tätiges Unternehmen mit...
# 4   Data Scientist Advanced Analytics (DSAA) EMEA ...
# 5   - Die Hauptaufgabe dieser Rolle besteht darin,...
# 6   - Der Incumbent ist für wichtige Aspekte entla...
# 7   - Die Person wird eng mit anderen Funktionen (...
# 8   -  Demonstration von Thought Leadership und in...
# 9                                  WAS SIE MITBRINGEN
# 10  - Universitätsabschluss im quantitativen Berei...
# 11  - Mehrjährige Berufserfahrung in der progressi...
# 12  - Erfahrung in den Bereichen Modellierung des ...
# 13  - Umfassendes Verständnis der Personalisierung...
# 14  - Erfahrung im Umgang und in der Analyse versc...
# 15  - Die Fähigkeit, funktionsübergreifende Teams ...
# 16  - Strategischer Geschäftssinn, Ergebnisorienti...
# 17  - Nachgewiesene Erfolgsbilanz beruflicher Erfo...
# 18                                     IHRE BEWERBUNG
# 19  Sie suchen eine Herausforderung, in der Sie Ih...
# 20  Die Stellenbeschreibung kann nicht vollständig...,                                                     0
# 0          Data Scientist Infektionsforschung (w/m/d)
# 1                                         Brunel GmbH
# 2                                 Stellenbeschreibung
# 3   Sie suchen eine neue Herausforderung in einem ...
# 4                                Arbeitsbeschreibung:
# 5   - Sie sind verantwortlich für die Koordination...
# 6   - Zudem erstellen Sie wissenschaftliche Analys...
# 7   - Auch die Beantragung von Drittmitteln fällt ...
# 8   - Des Weiteren analysieren Sie die Prozesse im...
# 9   und übertragen die Vorgaben der Prozesse an di...
# 10  - Sie übernehmen die inhaltliche Gestaltung de...
# 11  - Zusätzlich unterstützen Sie Lehrtätigkeiten ...
# 12                                        Ihr Profil:
# 13  - Abgeschlossenes Hochschulstudium im Bereich ...
# 14  -Informatik, Ingenieurswissenschaften oder ein...
# 15  - Berufserfahrung im Bereich der Quantitativen...
# 16                - Erfahrung in der Teamkoordination
# 17  - Kenntnisse im Bereich Machine Learning und S...
# 18  - Erste Erfahrung in der Konzeption und Durchf...
# 19  - Kenntnisse in statistischen Methoden und ver...
# 20  - Erste Erfahrung im Bereich Ausbruchsuntersuc...
# 21  Infektionsepidemiologie (z.B. EPIET, EIS, PAE,...
# 22  - Sehr gute Deutschkenntnisse sowie gute Engli...
# 23                                        Wir bieten:
# 24  Arbeiten bei Brunel bedeutet Vielfalt – vom mi...
# 25                                       Über Brunel:
# 26  Arbeiten bei Brunel bedeutet: Attraktive Arbei...,                                                     0
# 0      Data Analyst - Customer Relations / IT (m/w/d)
# 1                                    Campusjäger GmbH
# 2                                            Aufgaben
# 3                                  Was erwartet dich?
# 4   Du unterstützt das Management bei der Entwickl...
# 5   Du bereitest und visualisierst Analyse-Ergebni...
# 6   Du erstellst Change Requests und übernimmst ad...
# 7   Du übernimmst Projekte im Customer-Relations B...
# 8   Du unterstützt das Management bei der Entwickl...
# 9                                       Anforderungen
# 10                        Was solltest du mitbringen?
# 11  Du hast erfolgreich ein Studium oder eine Ausb...
# 12  Hohe Zahlenaffinität, ausgeprägtes analytische...
# 13  Du verfügst bereits über Erfahrungen in den Be...
# 14  Du bist sicher im Umgang mit MS Office Paket u...
# 15  Du hast eine Hands-on Mentalität und bist ein ...
# 16  Du verfügst über gute Deutsch- und Englischken...
# 17                                           Benefits
# 18                                Was bieten wir dir?
# 19  Einen spannenden Arbeitsplatz in einem wachstu...
# 20  Ein freundliches Team in dem man als Mensch wi...
# 21  Ein Umfeld in dem man viel lernen und auch Ver...
# 22  Eine umfangreiche Einarbeitung in unsere Produ...
# 23  Die Mitgestaltung der positiven Unternehmensku...
# 24  Eine attraktive Vergütung und langfristige Ent...
# 25  Subventionierte HVV Profi Card und Firmensport...,                                                     0
# 0                              Data Scientist (m/w/d)
# 1                                      dotSource GmbH
# 2                                 Stellenbeschreibung
# 3                              Data Scientist (m/w/d)
# 4   dotSource, das sind über 300 Digital Natives m...
# 5   6 Gründe, warum DU ein Teil der dotSource werd...
# 6   1. Von Beginn an: spannende Projekte mit namha...
# 7   2. Unser dotSource BootCamp garantiert Dir ein...
# 8   3. Du bekommst ständig neue Chancen Dich weite...
# 9   4. Deine Work-Life-Balance liegt uns am Herzen...
# 10  5. Getränke-Flatrate, Obstkörbe, Tischkicker, ...
# 11    6. Und das Wichtigste: WIR FREUEN UNS AUF DICH!
# 12                                 Das erwartet Dich:
# 13  Auswahl und Anpassung von Algorithmen zur Lösu...
# 14  Adressatengerechte Aufbereitung und Modellieru...
# 15          Erstellung und Aufbereitung von Analysen
# 16  Anwendung explorativer Verfahren zur Mustererk...
# 17  Projekt-Steuerung, beginnend bei der Analyse b...
# 18                                Das bringst Du mit:
# 19  Erfolgreich abgeschlossenes wirtschaftswissens...
# 20  Gute Kenntnisse in den einschlägigen Technolog...
# 21  Erfahrung in der Arbeit mit Datenstrukturen, -...
# 22  Idealerweise Erfahrungen mit Analytics- bzw. D...
# 23  Wenn Du es digital magst, dann sende uns Deine...
# 24  Solltest Du deine Unterlagen gerade nicht zur ...,                                                     0
# 0     WEB ANALYST / DATA SCIENTIST E-COMMERCE (M/W/D)
# 1                                               Falke
# 2        EINE HERAUSFORDERUNG MIT AN­ZIE­HUNGS­KRAFT:
# 3   Analyse und Bewertung des Kauf- und Nutzerverh...
# 4   Ableitung von Maßnahmen zur Optimierung der We...
# 5   Marktanalyse sowie die Aufbereitung von länder...
# 6        Aufbereitung von aussagekräftigen Reportings
# 7                Mitarbeit in strategischen Projekten
# 8                    IHR PROFIL SITZT WIE ANGEGOSSEN:
# 9   Erfolgreich abgeschlossenes Studium der Betrie...
# 10  Einschlägige Berufserfahrung in einer vergleic...
# 11  Sehr gute analytische Fähigkeiten und damit ei...
# 12  Versierter Umgang mit MS-Office Anwendungen - ...
# 13  Gute Kenntnisse zu datenschutzrechtlichen Them...
# 14  Strukturierte, organisierte und ergebnisorient...
# 15  Kommunikationsstarker Teamplayer mit zuverläss...
# 16   Sehr gute Englischkenntnisse in Wort und Schrift
# 17                 UNSER ANGEBOT LIEGT VOLL IM TREND:
# 18  In einer Welt der Massenproduktion sind eine v...
# 19  Als inhabergeführtes Familienunternehmen wisse...,                                                     0
# 0                             Data Scientist (m/w/d)
# 1                                             Ferchau
# 2                                 Stellenbeschreibung
# 3   Sie sind bereit für eine neue Herausforderung?...
# 4                              Data Scientist (m/w/d)
# 5                                      Ihre Aufgaben:
# 6   Ideenreich und kalkulierend - Ihre Aufgabe umf...
# 7   Planung, Konzeption, Umsetzung und Wartung von...
# 8                  Erarbeitung analytischer Use Cases
# 9   Auswahl und Anwendung statistischer Verfahren,...
# 10  Visuelle Darstellung der quantitativen Informa...
# 11  Programmierung und Weiterentwicklung von Daten...
# 12  Technologie und Teamspirit - Ihr Arbeitsplatz ...
# 13  Individuelle Karrierebegleitung durch dialogor...
# 14     Entwicklung bereichsübergreifender Kompetenzen
# 15  Individuelle Karriere-Programme für Ihre Entwi...
# 16                              Ihre Qualifikationen:
# 17  Sie sind mehr als gut vorbereitet - Ihr Know-h...
# 18  Abgeschlossene Ausbildung im IT-Bereich, Studi...
# 19  Praxisorientierte Anwendung von Methoden der D...
# 20  Praktische Erfahrung in der Programmierung mit...
# 21                          Gute Datenbank-Kenntnisse
# 22  Erfahrung mit analytischen und statistischen F...
# 23  Das ist die abwechslungsreiche Herausforderung...,                                                     0
# 0                              Data Scientist (w/m/d)
# 1                                   Handelsblatt GmbH
# 2                                     Deine Aufgaben:
# 3   Konzeption und Durchführung von Data-Science P...
# 4   Entwicklung und Operationalisierung von Scores...
# 5   (Proaktive) Analyse von Daten aus verschiedene...
# 6   Gemeinschaftliche Erarbeitung einer business-c...
# 7                                        Dein Profil:
# 8   Erfolgreich abgeschlossenes Studium der Betrie...
# 9   Erfahrung in den Bereichen Data Science, Data ...
# 10  Sehr gute Kenntnisse in SQL und Python, Kenntn...
# 11  Hohe Affinität für digitale Produkte und große...
# 12  Erfahrungen im Projektmanagement und in der Be...
# 13                                        Wir bieten:
# 14      Eine faire und leistungsorientierte Vergütung
# 15          Ein angenehmes und modernes Arbeitsumfeld
# 16                                   Mobiles Arbeiten
# 17  Gute Sozialleistungen (wie z.B. 30 Tage Urlaub...
# 18       Individuelle Weiterentwicklungsmöglichkeiten,                                                     0
# 0                      Specialist Master Data (m/w/d)
# 1                                  König GmbH & Co KG
# 2                          Verstärken Sie unser Team!
# 3   Zur unbefristeten Festanstellung bei uns und f...
# 4                      Specialist Master Data (m/w/d)
# 5                                       Ihre Aufgaben
# 6   Anlage und Änderung und Pflege von Stammdaten ...
# 7            Dubletten Bereinigung, Mandatsverwaltung
# 8   Unterstützung anderer Fachbereiche bei komplex...
# 9   Prozessverantwortung sowie Pflege der entsprec...
# 10  Übernahme administrativer Aufgaben im Bereich ...
# 11                          projektbezogene Mitarbeit
# 12                                         Ihr Profil
# 13            Abgeschlossene kaufmännische Ausbildung
# 14    Sichere Anwendung der Microsoft Office Produkte
# 15                      Gute Anwendungskenntnisse SAP
# 16  Selbstständige, strukturierte und zielorientie...
# 17  Hohes Maß an Engagement, Motivation und Eigeni...
# 18                Soziale Kompetenz und Teamfähigkeit
# 19                                         Wir bieten
# 20                       Unbefristeter Arbeitsvertrag
# 21                   Anwendung des iGZ Tarifvertrages
# 22                               Pünktliche Zahlungen
# 23                        Urlaubs- und Weihnachtsgeld
# 24                                 Jubiläumszahlungen
# 25  Vermögenswirksame Leistungen bereits nach sech...
# 26                        Bis zu 30 Tage Jahresurlaub
# 27  Ein großartiges Team, was jederzeit für Sie da...
# 28                                         Interesse?
# 29            Dann freuen wir uns auf Ihre Bewerbung.
# 30  Mit nur wenigen Klicks erfolgreich zum neuen Job!,                                                     0
# 0                             Data Scientist (w/m/d)
# 1                            Schwarz Produktions GmbH
# 2   Vertragsart: Unbefristet Zu besetzen: ab sofor...
# 3                                       DAS MACHST DU
# 4   Datenanalyse in Geschäftsprozessen und Ableitu...
# 5   eigenständige Durchführung von statistischen A...
# 6   selbstständige Entwicklung und Implementierung...
# 7   Übernahme von Projektleitungsaufgaben im Berei...
# 8   Vorantreiben des digitalen Wandels im Unterneh...
# 9                                     DAS LIEFERST DU
# 10  erfolgreich abgeschlossenes Studium z.B. der (...
# 11  einschlägige Erfahrung bei der Umsetzung, Impl...
# 12  Expertenwissen im Umgang mit gängigen Analytic...
# 13  sehr gute Kenntnisse im Design und der Umsetzu...
# 14  starke analytische und konzeptionelle Fähigkei...
# 15  verhandlungssichere Sprachkenntnisse in Deutsc...
# 16                                  Reisebereitschaft
# 17                                    DAS LIEFERN WIR
# 18  ein verantwortungsvolles und abwechslungsreich...
# 19  die Möglichkeit, deine Ideen und Kompetenzen e...
# 20  individuelle Weiterbildungs- und Entwicklungsm...
# 21  ein entwicklungsorientiertes Arbeitsumfeld ver...
# 22                           AUF WAS WARTEST DU NOCH?
# 23  Bewirb dich einfach direkt online bei der Schw...,                                                     0
# 0   Datenbankspezialist Data Scientist/Data Analys...
# 1                                           Grinnberg
# 2    - Raum Wiesbaden - Datenbanken - Data Experto...
# 3   Öffnen Sie Ihrem beruflichen Erfolg die Tür mi...
# 4                     Persönliche IT-Job-Perspektiven
# 5   Sie bestimmen selbst Ihren Karriereweg und wer...
# 6   Die Möglichkeit auf spannende Projekttätigkeit...
# 7   Eine Unternehmenskultur, die auf den Werten Re...
# 8                Arbeit in einem bunt gemischten Team
# 9   Leistungsgerechte Vergütung, unabhängig von Se...
# 10  Ausgiebiges Angebot an gemeinsamen Veranstaltu...
# 11  Direkter Austausch mit der Geschäftsführung - ...
# 12  Individuelle HO Vereinbarungen, angepasst an I...
# 13  ein (regelmäßig genutzter) Tischkicker; Sports...
# 14                      40h/Woche bei 30 Urlaubstagen
# 15   (Fließende Deutschkenntnisse sind Voraussetzung)
# 16               Die Herausforderungen dieses IT-Jobs
# 17  Konzeption/Entwicklung /Betreuungder individue...
# 18                          Eingesetzte Technologien:
# 19                                       Access/Excel
# 20            Statistik-Tools (R, EViews, SPSS, etc.)
# 21                                      Oracle PL/SQL
# 22              Deine Qualifikation für diesen IT-Job
# 23  Erfahrung im Umgang mit Statistik-Tools (R, EV...
# 24        Gute Programmierkenntnisse in Oracle PL/SQL
# 25  Berufserfahrung im Bereich der Statistik, spez...
# 26  Passt die Position für Dich – oder magst Du we...
# 27  Schick uns einfach Deinen Lebenslauf. Wir prüf...
# 28  So können mit Dir die vielen Möglichkeiten bes...,                                                     0
# 0   19652: IT Projekt Manager (m/w/d) - Data Analy...
# 1                               Cs2 ITEC GmbH & Co.KG
# 2                                 Stellenbeschreibung
# 3   Cs2 ITEC bietet Ihnen als Berufseinsteiger ode...
# 4   Bei spannenden und abwechslungsreichen Tätigke...
# 5                               Das bieten wir Ihnen:
# 6   - Abwechslungsreiche Tätigkeiten in einem span...
# 7   - Internationale Großprojekte bei namhaften Ku...
# 8   - Mitarbeit in einem sympathischen und motivie...
# 9          - Angenehmes und kollegiales Arbeitsumfeld
# 10  - Interessante Perspektiven für die fachliche ...
# 11  - Attraktive Vergütung und flexible, familienf...
# 12                     Diese Aufgaben warten auf Sie:
# 13  - Aufbau eines digital gestützten Kennzahlensy...
# 14  - Administration der bestehenden manuellen Ken...
# 15  - Integration eines MES-Systems in den Produkt...
# 16  - Anbindung von Lagerverwaltungssystemen an SA...
# 17  - Umstellung von manuellen Auswertemethoden de...
# 18                        Was Sie mitbringen sollten:
# 19  - Abgeschlossenes Studium im Bereich (Wirtscha...
# 20                          - Erste Berufserfahrungen
# 21            - Erfahrung mit SAP und Datenmanagement
# 22     - Erweiterte Kenntnisse mit Excel inkl. Makros
# 23  - Kenntnisse mit Power BI oder vergleichbaren ...
# 24  - Wünschenswert sind Erfahrungen in der Erstel...
# 25                           Wir freuen uns auf SIE !,                                                     0
# 0   Portfoliomanager (m/w/d) mit Schwerpunkt Data ...
# 1                                        Südweststrom
# 2                                      Ihre Aufgaben:
# 3   Analyse und Bewirtschaftung der Strom- und Gas...
# 4   Ansprechpartner (m/w/d) für unsere Kunden rund...
# 5   Weiter­entwicklung der Produkte und Dienst­lei...
# 6   Projektaufgaben mit Schwerpunkt Data Science: ...
# 7                                         Ihr Profil:
# 8   Abgeschlossenes Studium im Bereich der Wirtsch...
# 9   Sehr gute IT-Kenntnisse (insbesondere R oder P...
# 10  Hervorragende analytische Fähigkeiten und math...
# 11  Interesse an Energie- und Finanzmärkten sowie ...
# 12  Die Fähigkeit, vernetzt zu denken und komplexe...
# 13  Teamplayer mit ausge­prägter Kommunikations­st...
# 14         ergebnis- und service­orientiertes Handeln
# 15                                  Wir bieten Ihnen:
# 16  eine unbefristete Festanstellung – wir möchten...
# 17  eine fundierte und individuell zugeschnittene ...
# 18  flexible Arbeitszeiten – mit vielen Teilzeitmo...
# 19  abwechslungsreiche und anspruchsvolle Aufgaben...
# 20  eine leistungsgerechte Vergütung mit einem 13....
# 21  die Zusammenarbeit mit einem engagierten Team ...,                                                     0
# 0                       (Senior) Data Analyst (w/m/d)
# 1                                            Lunapark
# 2                    DAS BRINGST DU IDEALERWEISE MIT:
# 3   Du liebst und atmest Analytics und hast Lust d...
# 4   Mit der Google Cloud hast Du bereits mehrfach[...
# 5   Dein Studium der Mathematik, Wirtschaftswissen...
# 6   Einschlägige Erfahrung mit Google Analytics, D...
# 7   Du kennst Dich mit Datenbanken, Scripting und ...
# 8   Hohe analytische Fähigkeiten bei der Verarbeit...
# 9   Du hast Spaß an der Erstellung von Abfragen, B...
# 10  Du bist ein Teamplayer und kannst gut und auch...
# 11  Wenn Du Lust auf viel Eigenverantwortung und G...
# 12                             SO SIEHT DEIN JOB AUS:
# 13  In deiner Funktion als (Senior) Data Analyst o...
# 14                                     DEINE AUFGABEN
# 15  Du leitest aus den Business-Needs Anforderunge...
# 16  Auf Basis der erhobenen Daten machst Du die Us...
# 17  Du bist Ansprechpartner*in für das gesamte Unt...
# 18  In Zusammenarbeit mit Data Developern aus unse...
# 19  Du bist sowohl für das Training und Enablement...
# 20  Die Entwicklung und Bereitstellung von automat...
# 21  Präsentationen bei Kundenmeetings, Workshops u...
# 22     Vermitteln von Know-How an Kunden und Kollegen
# 23                                    WAS WIR BIETEN:
# 24  Profitiere von den Erfahrungen eines qualifizi...
# 25  Flexible Arbeitszeiten für Frühaufsteher und L...
# 26  Attraktive Sozialleistungen: Betriebliche Alte...
# 27    Wir fördern Fort- und Weiterbildungsmaßnahmen
# 28  Teilnahme an Branchenveranstaltungen und -events
# 29   Fit und Fun: Yogamorgen für alle Interessierten
# 30  Durch die Möglichkeit eines Job-Tickets sparen...
# 31  Der Rhein ist direkt vor unserer Tür, ideal fü...,                                                     0
# 0   Wissenschaftliche/r Mitarbeiter Datenanlyse (m...
# 1                                   Bundeskriminalamt
# 2                                 Stellenbeschreibung
# 3   Wissenschaftliche Mitarbeiterin / Wissenschaft...
# 4                                 Standort: Wiesbaden
# 5                      Arbeitszeit: Vollzeit/Teilzeit
# 6                         Bewerbungsfrist: 15.04.2021
# 7        Arbeitsbeginn: zum nächstmöglichen Zeitpunkt
# 8                      Vergütung: EG 13 TV EntgO Bund
# 9   Unterstützen Sie uns als Wissenschaftliche Mit...
# 10  Machen auch Sie das Richtige und bewerben Sie ...
# 11  Ihre Aufgaben Planung und Durchführung von For...
# 12  ▪ Untersuchung und Bewertung neuer methodische...
# 13  ▪ Eigenverantwortliche Methoden- und Modellent...
# 14  ▪ Entwicklung und Einsatz von Anwendungen zur ...
# 15       ▪ Nationale und internationale Gremienarbeit
# 16                                Das bringen Sie mit
# 17  ▪ Abgeschlossenes wissenschaftliches Hochschul...
# 18  ▪ Fundierte Kenntnisse im Bereich der intellig...
# 19  ▪ Grundlegende Kenntnisse in relevanten Analyt...
# 20                                             On Top
# 21  ▪ Eine dreijährige Berufserfahrung in einem en...
# 22  ▪ Gute Kenntnisse in relevanten Programmierspr...
# 23  ▪ Gute Englischkenntnisse in Wort und Schrift;...
# 24  ▪ Bereitschaft zu mehrtägigen Dienstreisen im ...
# 25  ▪ Sie haben eine sehr gute mündliche und schri...
# 26                               Das bieten wir Ihnen
# 27  ▪ Ein gutes Gefühl: sinnstiftender Job in eine...
# 28  ▪ Work-Life-Balance: 30 Tage Urlaub, Überstund...
# 29  ▪ Ein sportliches Team: vielfältiges Sportange...
# 30  ▪ Langfristig planbar: sicherer Job im Öffentl...
# 31  ▪ Entgeltgruppe 13 TV EntgO Bund, Eingruppieru...
# 32  Bewerben Sie sich jetzt – und kommen Sie in un...,                                                     0
# 0   Berater Business Intelligence (m/w/d) – (Data ...
# 1                                         initions AG
# 2   Zur Verstärkung unseres Teams am Standort Hamb...
# 3   Die initions AG bietet im Geschäftsbereich „Bu...
# 4   Wir arbeiten an den zentralen Stellen, von den...
# 5   initions wurde vom Stifterverband für die Deut...
# 6   Möchtest Du das “Dahinter” verstehen, an den n...
# 7                  Dann sollten wir uns kennenlernen!
# 8              Je nachdem, ob Deine Leidenschaft ist:
# 9   Datenbankmodelle zu entwerfen, Analysen durchz...
# 10  IT Infrastruktur‑, Security- und Cloudkonzepte...
# 11  mathematisch statistische Analysen durchzuführ...
# 12  betriebswirtschaftliche Prozesse zu durchdring...
# 13  oder Du noch gar nicht festgelegt bist, stehen...
# 14  Über Deine vollständigen Bewerbungsunterlagen ...
# 15  Wichtig für die Aufgabe ist, dass Du verhandlu...
# 16  Für weitere Fragen steht Dir Deine Ansprechpar...,                                                     0
# 0   Business Analyst / Data Scientist Sales / Mark...
# 1                                      Mediatech GmbH
# 2   Table.Media ist ein Teil der Trafo.Gruppe. Wir...
# 3   Mit Table.Media gestalten wir den Qualitätsjou...
# 4   Den Auftakt macht China.Table mit der größten ...
# 5   Zur Unterstützung unseres Teams suchen wir zum...
# 6           Bitte bewirb dich mit Anschreiben und CV.
# 7                                            Aufgaben
# 8   Du bist verantwortlich für die Datenqualitätss...
# 9   Du verfügst über sehr gute Kenntnisse in Googl...
# 10  Du hast Erfahrung im Aufbau und in der Optimie...
# 11  Du bist Spezialist in mehreren der folgenden B...
# 12  Du verantwortest den Aufbau und die Erstellung...
# 13  Du unterstützt die Boards sowie die Sales- und...
# 14  Du trägst die Verantwortung der CRM Dateneigen...
# 15  Durchführung von Ad-hoc-Analysen sowie Verantw...
# 16  Du bist ein Vordenker für Projekte im Kontext ...
# 17                                      Qualifikation
# 18  Du hast einen Abschluss in BWL, Mathematik, Da...
# 19  Du hast mindestens 3 Jahre Berufserfahrung im ...
# 20  Erfahrung mit Google Data Studio ist von Vorteil.
# 21  Du bist vernetzt und hast gute Kenntnisse der ...
# 22          Du bist fließend in Deutsch und Englisch.
# 23  Du bist strukturiert, analytisch und interdisz...
# 24  Du bist entscheidungsstark und kannst dich sel...
# 25                   Du hast eine Hands-On-Mentalität
# 26  Du bist ein Team Player, aber kannst auch selb...
# 27                          Du findest gerne Lösungen
# 28                                           Benefits
# 29     Hoher Grad an Eigenverantwortung und Autonomie
# 30  Wachstumskultur mit starken persönlichen und b...
# 31  eine offene Atmosphäre mit Partnern und Kolleg...
# 32  Büro in Berlin Mitte mit einem schönen Ausblic...
# 33                          und Obst, Kaffee und Tee.
# 34  Wenn Du ein qualifizierte/r BI-Pro mit Faible ...,                                                     0
# 0                       SENIOR DATA SCIENTIST (M/W/D)
# 1                        AIM Agile IT Management GmbH
# 2   Als Senior Data Scientist (m/w/d) realisierst ...
# 3   Verstärke unser erfolgreich wachsendes AI/Mach...
# 4                                            Aufgaben
# 5   Abhängig von Deinen Stärken und Erfahrungen ni...
# 6   Analyse und Übersetzung von Aufgabenstellungen...
# 7   Exploration, Analyse und Visualisierung komple...
# 8   Realisierung skalierbarer Data/Feature Process...
# 9   Erprobung, Auswahl und Verbesserung von Machin...
# 10   Nutzung analytischer und statistischer Verfahren
# 11  Anwendung von Verfahren für Modell Vergleich, ...
# 12  Produktive Integration und Automatisierung von...
# 13  Einbettung in Lösungen für Endanwender (Human-...
# 14  Einbettung in das Monitoring der Modell Leistu...
# 15  Refactoring und Retrofitting in unsere Standar...
# 16  Enge Zusammenarbeit mit den Teams für Software...
# 17  Unser Team sorgt dabei für kontinuierlichen Wi...
# 18                                      Qualifikation
# 19  Abschluss im Bereich Mathematik, Informatik, C...
# 20  Du besitzt fundierte Kenntnisse und praktische...
# 21  Idealerweise verfügst Du über gute Kenntnisse ...
# 22  Du hast bereits mit verschiedenen Frameworks u...
# 23  Du arbeitest gern im Team und präsentierst Dei...
# 24               Gute Deutsch- und Englischkenntnisse
# 25                                           Benefits
# 26  Hohe Aufmerksamkeit für Deine persönliche Ent...
# 27  Intensive Weiterbildungsmöglichkeiten (z.B. ag...
# 28  Eigenverantwortliches Arbeiten mit viel Gestal...
# 29  Eine agile, professionelle und innovative Orga...
# 30  Flache Hierarchien, kurze Abstimmungswege und ...
# 31  Vertrauensarbeitszeit, Möglichkeiten zur Heima...
# 32  Einen attraktiven Arbeitsplatz in zentraler La...
# 33  Starken Kaffee, frisches Obst und gekühlte Sof...
# 34  Wir freuen uns auf Deine aussagekräftigen Bewe...
# 35           und Deines gewünschten Eintrittstermins.,                                                     0
# 0   Head of Software: Softwareentwickler/Informati...
# 1                                          AITAD GmbH
# 2                                     Deine Aufgaben:
# 3   Organisation/Teamleitung vom internen Personal...
# 4   Kommunikation zur Geschäftsführung (z.B. beim ...
# 5   Analyse, Aufbereitung und Machine-Learning-Mod...
# 6   Professionelle, systemorientierte Programmieru...
# 7   Implementierung von Kommunikationsprotokollen ...
# 8   Erweitern und Aufbauen weiterer GPU-Server bzw...
# 9   Übernahme der Koordination ausländischer Freel...
# 10  Zunehmend: Mitentwicklung von Hybridsystemen m...
# 11                                       Dein Profil:
# 12                  Du verfügst über Praxiserfahrung.
# 13            Du schätzt Autonomie und Verantwortung.
# 14  Du bist leistungsfähig und intrinsisch motiviert.
# 15                       Du liebst Herausforderungen.
# 16  Du kennst und befürwortest agiles Arbeiten (z....
# 17  Du arbeitest gern interdisziplinär in verschie...
# 18  Du bist gern hardwarenah und im Embedded-Gebie...
# 19  Du kennst dich mit Cloud-Entwicklungsprozessen...
# 20  Du besitzt fundierte Kenntnisse in professione...
# 21  Du bist bereit, auch zunehmend mit Hardwarebes...
# 22  Du kennst dich mit Datenanalyse und Machine Le...
# 23  Du kennst dich grundlegend mit RTOS, Embedded ...
# 24  Du hast Grundkenntnisse in applikativen Schnit...
# 25  Optimal: Du kennst dich zudem im Groben mit Si...
# 26  Dir bereitet es Freude, Algorithmen an geringe...,                                                     0
# 0                              Data Scientist (m/w/d)
# 1                                         IKK Südwest
# 2                            Was dürfen Sie erwarten?
# 3   eine Zielvergütung nach IKK-TV im Rahmen von m...
# 4   Flexibilität hinsichtlich Arbeitszeit und -ort...
# 5   30 Tage Urlaub; Heiligabend und Silvester sind...
# 6      80 % Weihnachtsgratifikation sowie Urlaubsgeld
# 7   Familienzulage in Höhe von monatlich 130 € pro...
# 8                    eine betriebliche Altersvorsorge
# 9   optimale Vereinbarkeit von Beruf, Familie und ...
# 10  eine gezielte Weiterentwicklung durch bedarfsg...
# 11  Maßnahmen zur Förderung der Gesundheit unserer...
# 12                      Welche Aufgaben erwarten Sie?
# 13  die Beratung zur Strategieentwicklung im Verso...
# 14  die Simulation und Kalkulation von Vergütungsm...
# 15    die Analyse von Bestands- und Selektivverträgen
# 16  die Durchführung von Versorgungsanalysen auf B...
# 17  die Anwendung statistischer Verfahren zur Durc...
# 18  die Planung, Entwicklung und Durchführung komp...
# 19  die Entwicklung lernender Systeme und Prognose...
# 20  der Transfer fachspezifischer Fragestellungen ...
# 21  die Konzeptionierung und Durchführung gesundhe...
# 22  die Teilnahme an Ausschüssen, Gremien und exte...
# 23  die Durchführung bzw. Leitung von Strategiekre...
# 24  die Mitarbeit in bzw. Leitung von Projekten un...
# 25                          Wie sieht Ihr Profil aus?
# 26  ein (Fach-)Hochschulstudium der Wirtschaftswis...
# 27  mehrjährige Berufserfahrung in der Anwendung s...
# 28    sehr gute Deutschkenntnisse in Wort und Schrift
# 29  analytisches, strategisches und unternehmerisc...
# 30                                Lösungsorientierung
# 31  sehr gute adressatengerechte kommunikative Fäh...,                                                     0
# 0   Data Scientist Process Intelligence (m/w/d) fü...
# 1                                         Symate GmbH
# 2   Gestalte mit uns den Bereich der KI-gestützten...
# 3                         Deine neue Herausforderung:
# 4   Umsetzung von Datenanalyse Pipelines unter Ein...
# 5   Entwicklung von intelligenten Modellen und Sof...
# 6   Gelegentliche Präsentationen der Ergebnisse un...
# 7   Auseinandersetzen mit kundenspezifischen Produ...
# 8    Austausch mit Fachexperten und Systemlieferanten
# 9                         Was Du mitbringen solltest:
# 10  Solide Programmierkenntnisse in Scala oder ein...
# 11  Dies ist eine Anzeige von ITsax.de des Empfehl...
# 12  Schlagworte: Java, Java-entwickler, Programmie...,                                                     0
# 0   Data Scientist, Schatzsucher und Managementber...
# 1                                          CTcon GmbH
# 2   Das Profil mag ungewöhnlich erscheinen. Das An...
# 3                                            Die Idee
# 4   Wir suchen Menschen, die drei Fähigkeiten vere...
# 5                                  Wer kann so etwas?
# 6   Menschen, die in Statistiken mehr sehen als nu...
# 7                               Warum wollen wir das?
# 8   Unsere Erfahrung zeigt, dass viele Data Scient...
# 9   Mit Fachwissen und mit persönlicher Intuition ...
# 10                           Was haben wir zu bieten?
# 11  Optimale Rahmenbedingungen: Innerhalb unseres ...
# 12                            Flexible Arbeitsmodelle
# 13  Freie Wahl des Bürostandortes mit Option zum n...
# 14                             Homeoffice-Möglichkeit
# 15          Bei Bedarf Anpassung des Arbeitseinsatzes
# 16                              Weiterbildungsangebot
# 17                Begleitung durch persönlichen Coach
# 18                        Persönliches Bildungsbudget
# 19                                    Fellow-Programm
# 20                Außergewöhnliche Unternehmenskultur
# 21  Open Door Policy und monatliche Meetings zu ak...
# 22  Regelmäßige Mitarbeiterbefragung und Diskussio...
# 23             Teamevents, Sommerfeste, Offsites etc.
# 24                  Wie sieht dein Aktionsradius aus?
# 25  Als Berater bei unseren Kunden und im Backoffi...
# 26  Anwendung statistischer Methoden wie deskripti...
# 27  Verfahren im Bereich Data Mining & Machine Lea...
# 28  Erfahrung in der Umsetzung von Data Pipelines ...
# 29  Analyse großer Datenmengen mit Apache Stacks w...
# 30  Anwendung des Methodenwissens auf betriebswirt...
# 31  Managementorientierte Zusammenfassung und Präs...
# 32  Adressatengerechte Kommunikation komplexer, an...
# 33          Übernahme erster Teilprojektverantwortung
# 34                  Mitarbeit an Querschnittsaufgaben
# 35   Wo könnte deine neue professionelle Heimat sein?
# 36  CTcon ist eine führende, international ausgeri...,                                                     0
# 0                              Data Scientist (m/w/d)
# 1                      Schickler Unternehmensberatung
# 2   Als Data Scientist bist Du Teil unseres SCHICK...
# 3   Analyse von großen Daten und Identifikation vo...
# 4   Bereinigung von Daten (z.B. mit Python Pandas ...
# 5   Entwicklung von Machine Learning-Modellen (z.B...
# 6   Visualisierung und Aufbereitung der Ergebnisse...
# 7   Optimierung der Modelle, Begleitung von real-w...
# 8   Bei uns bist Du richtig, wenn Du wissbegierig ...
# 9   Studium in (Wirtschafts-)Mathematik, Informati...
# 10  Von Vorteil ist relevante Berufserfahrung im B...
# 11  Analytische Fähigkeiten, Denken in Daten und S...
# 12  Fähigkeit Business Prozesse zu verstehen und L...
# 13  Programmiererfahrung, idealerweise in Python (...
# 14  Erfahrung in Machine Learning-Konzepten und Fr...
# 15  Unternehmerische Denkweise und ausgeprägte tec...
# 16                                   Warum SCHICKLER?
# 17                               Bewusst & Nachhaltig
# 18                        Firmenrad statt Firmenwagen
# 19                                  Mitten in Hamburg
# 20                             Bahncard privat nutzen
# 21                       Handy & Laptop privat nutzen
# 22                              Hunde sind Willkommen
# 23                                         Homeoffice
# 24                              Große Getränkeauswahl
# 25                                       Barrierefrei
# 26  Bist Du neugierig geworden? Dann bewirb' Dich ...,                                                     0
# 0       Data Scientist (m/w/d) Simulation Engineering
# 1                                         Synaos GmbH
# 2   SYNAOS ist ein 2018 gegründetes Software-Start...
# 3                                          Wir bieten
# 4   Schnell wachsendes, top finanziertes Start-Up ...
# 5   Herausfordernde Aufgaben beim Entwickeln unser...
# 6   Pionierarbeit in der Intralogistik für die Fab...
# 7     Als ersten Kunden Volkswagen, einen DAX-Konzern
# 8   Kreatives Arbeitsumfeld mit kurzen Entscheidun...
# 9               Hardware und Betriebssystem nach Wahl
# 10               Beteiligungsprogramm für Mitarbeiter
# 11  Unbefristete Arbeitsverträge sowie 30 Urlaubstage
# 12       Flexible Arbeitszeiten inklusive Home-Office
# 13                                      Deine Mission
# 14  Bei welchen Aufgaben braucht die Abteilung Unt...
# 15  Die Projektrealisierung beim Kunden ist das le...
# 16  Simulation ist ein wichtiges Asset um Inbetrie...
# 17  Projektrisiken im Anlauf können durch eine frü...
# 18  Immer häufiger ist Simulation auch im Sales re...
# 19  Skalierung der Simulationsidee und Integration...
# 20                             Was machst Du konkret?
# 21    Prozessaufnahme und -klärung in Kundenprojekten
# 22  Szenario-Definition im System entsprechend von...
# 23  Durchführung von Simulationsstudien und Analys...
# 24  Analyse von möglichen Engpässen und Ausarbeitu...
# 25  Interne Diskussion über Lösungsansätze zu Proz...
# 26  Präsentation von Arbeitsergebnissen (intern un...
# 27  Diskussion von Arbeitsergebnissen (intern und ...
# 28                                        Deine Werte
# 29  Teamorientierung und leben einer Lernkultur mi...
# 30  Selbständiges angehen von Problemen und kreati...
# 31  Pragmatisches und effizientes, aber dennoch sa...
# 32  Professionelles auftreten und Wertschätzen des...
# 33                                  Reisebereitschaft
# 34                                     Sinn für Humor
# 35                                 Das bringst Du mit
# 36                                             Können
# 37  Abgeschlossenes Studium der Fachrichtung Mathe...
# 38  Erfahrung in der Umsetzung von Simulationsproj...
# 39               Erfahrung im Umgang mit Analysetools
# 40  Fließendes Englisch und idealerweise gutes Deu...
# 41                             Technologie & Methoden
# 42                                               Java
# 43                   Kenntnisse in Python/R hilfreich
# 44  Git, ElasticSearch, Kibana, Kafka, MQTT, Postg...
# 45                                        Einstellung
# 46         Kommunikation und Fähigkeit zur Teamarbeit
# 47                         Strukturierte Arbeitsweise
# 48                                    Umsetzungswille,                                                     0
# 0                              DATA SCIENTIST (m/f/d)
# 1                             Westphalia DataLap GmbH
# 2                                DEIN UMFELD UND TEAM
# 3   Du glaubst an die Kraft von Daten? Du hast Lus...
# 4                          DEIN VERANTWORTUNGSBEREICH
# 5   Als Data Scientist (w/m/d) analysierst Du groß...
# 6   Du arbeitest gemeinsam mit einem Projektteam a...
# 7   Du analysierst und bereitest komplexe Daten au...
# 8   Du kennst statistische Methoden und Algorithme...
# 9   Du erstellst auf Basis der Kundendaten Modelli...
# 10  Du entwickelst Software, um diese für unsere K...
# 11  Weiterhin unterstützt du bei der Aufbereitung,...
# 12                                 DAS BRINGST DU MIT
# 13  Du hast einen sehr guten Hochschulabschluss mi...
# 14  Du hast 2-3 Jahre Berufserfahrung in der Softw...
# 15  Idealerweise konntest du diese Erfahrung in de...
# 16  Du wendest Technologien wie Docker, Javascript...
# 17  Du kannst sehr gute Kenntnisse in Python und D...
# 18  Du kennst die gängigen Standardbibliotheken zu...
# 19  Ein stark ausgeprägtes analytisches Denkvermög...
# 20  Verhandlungssichere Deutsch- und Englischkennt...
# 21                        DAS ERWARTET DICH BEIM WDL!
# 22  IMPACT. Als WDL-Kollege bist du für das Team u...
# 23  CHALLENGES.Vielfältige Projekte mit sichtbaren...
# 24  WDL TEAM.Wir punkten mit flachen Hierarchien, ...
# 25  HOW WE WORK.Neben einer familiären Atmosphäre,...
# 26  CULTURE.Neben regelmäßigen Teamevents, Teamlun...
# 27  Wenn das alles für Dich passt, dann suchen wir...
# 28         Klingt nach der richtigen Herausforderung?
# 29                Wir freuen uns auf Deine Bewerbung!,                                                     0
# 0                              Data Scientist (m/w/d)
# 1                                  WidasConcepts GmbH
# 2   Die Widas Technologie Services ist ein global ...
# 3   Zur Unterstützung unseres Entwicklerteams such...
# 4                                      Deine Aufgabe:
# 5      Analyse und Abstimmung der Kundenanforderungen
# 6   Untersuchung von Daten und ableiten von Anford...
# 7   Entwicklung, Training und Test von Modellen im...
# 8   Technische Umsetzung der Softwarelösungen auf ...
# 9                                 Was wir Dir bieten:
# 10                       Unbefristeter Arbeitsvertrag
# 11        Agiles Arbeiten in einem begeisterten Team​
# 12  Spannende Technologien und Projekte an der Lea...
# 13  Die Wahl zwischen Mac oder Dell sowie deinem b...
# 14  Offene Türen, gemeinsame Events, firmenweites ...
# 15  Getränkeflatrate für Wasser, Tee, Kaffee und j...
# 16                   Dein Profil, was uns überzeugt:​
# 17  Studium der (Wirtschafts-)Informatik oder verg...
# 18  Kenntnisse über BigData Technologien, wie Spar...
# 19  Erfahrung in der Softwareentwicklung mit Pytho...
# 20  Spaß an agiler Softwareentwicklung sowie Motiv...
# 21  Teamfähigkeit, Einsatzbereitschaft, Selbständi...
# 22          Fließende Deutsch- und Englischkenntnisse
# 23                Wir freuen uns auf Deine Bewerbung!
# 24  Benötigte Anlagen: Anschreiben, Lebenslauf, Ze...,                                                     0
# 0            Senior Data Scientist (w/m/d) in Hamburg
# 1                                     adesso IT Hanse
# 2   Wir gehören zu den Top-Adressen in der IT-Welt...
# 3   DEINE ROLLE - DAS WARTET AUF DICH Gestalte gem...
# 4   Du verfügst bereits über mehrjährige Erfahrung...
# 5   In diesem Kontext übernimmst du die folgenden ...
# 6   Du analysierst die Daten unserer Kunden nach T...
# 7   Je nach Erfahrungshintergrund verantwortest Du...
# 8   Unter Verwendung moderner Machine Learning und...
# 9                   DEINE SKILLS - DAS BRINGST DU MIT
# 10  Abgeschlossenes Studium oder Promotion der Inf...
# 11  Dies ist eine Anzeige von IThanse.de des Empfe...
# 12  Schlagworte: (Senior), Data, Scientist, (w/m/d...,                                                     0
# 0                       (Senior) Data Scientist (wmd)
# 1                                           adesso SE
# 2                   Deine Rolle - das wartet auf Dich
# 3   Gestalte gemeinsam mit uns die Line of Busines...
# 4   Du verfügst bereits über mehrjährige Erfahrung...
# 5   In diesem Kontext übernimmst du die folgenden ...
# 6   Du analysierst die Daten unserer Kunden nach T...
# 7   Je nach Erfahrungshintergrund verantwortest Du...
# 8   Unter Verwendung moderner Machine Learning und...
# 9                   Deine Skills - das bringst Du mit
# 10  Abgeschlossenes Studium oder Promotion der Inf...
# 11  Überzeugende Programmierkenntnisse in Python, ...
# 12  Erfahrung mit großen Datenmengen, z.B. Soziale...
# 13  Du hast dich im Studium oder in der Praxis sch...
# 14  Als Senior Consultant bringst Du sowohl Projek...
# 15  Eine hohe Ergebnis- und Kundenorientierung sow...
# 16                 Chancengeber - was adesso ausmacht
# 17  Unser Ziel ist es, dass du dich bei uns wohlfü...
# 18  Welcome Days - 2 Tage zum Reinkommen und Netzw...
# 19  Weiterbildung - über 120 Schulungen und Weiter...
# 20  Choose your own device - freie Wahl deiner Arb...
# 21               Events - fachlich und mit Spaßfaktor
# 22  Hemden- und Blusenreinigung - zweimal die Woch...
# 23  Sportförderung - Zuschuss zum Fitnessstudio un...
# 24  Mitarbeiterprämien - eine Vielzahl an Prämien ...
# 25  Auszeitprogramm - Raum für deine persönliche L...,                                                     0
# 0                              Senior Data Scientist
# 1                                         Carrypicker
# 2                                            Aufgaben
# 3   Du nutzt neueste Methoden aus dem Umfeld von K...
# 4   Du bist ein "Lösungsfinder" wenn es darum geht...
# 5   Du arbeitest im Schulterschluss mit dem Projek...
# 6                                       Qualifikation
# 7                     Grundsätzliche Qualifikationen:
# 8   Abgeschlossenes Studium mit analytisch-quantit...
# 9   Erfahrung in der Modellierung realer Fragestel...
# 10  Ausgeprägtes Methodenwissen in Statistik und M...
# 11                         Sicherer Umgang mit Python
# 12  Selbstständige und eigenverantwortliche Arbeit...
# 13               Gute Deutsch- und Englischkenntnisse
# 14                Weitere hilfreiche Qualifikationen:
# 15     Erfahrung im Umgang mit PostgreSQL und MongoDB
# 16  Kenntnisse in Softwareentwicklung und zugehöri...
# 17  Sicherer Umgang mit dem Betriebssystem Unix (i...
# 18                       Erfahrung im Logistikbereich
# 19                                           Benefits
# 20  Nachhaltigkeit, Transparenz und der Mut neue A...
# 21  Unser Team ist angetreten, um neue Wege zu geh...
# 22  Unser Angebot klingt wie gemacht für Dich? Dan...,                                                     0
# 0   Vertriebscontroller / Data Scientist (m/w/d) |...
# 1                                     Mercateo Gruppe
# 2   Die Mercateo Gruppe stellt als Betreiber von B...
# 3   Um die Herausforderungen unseres Wachstums nat...
# 4   Vertriebscontroller / Data Scientist (m/w/d) |...
# 5                                      Deine Aufgaben
# 6   Transparenz schaffen: Du stellst kundenspezifi...
# 7   Ganzheitlich denken: Du optimierst kennzahleng...
# 8   Zukunft mitgestalten: Als Mitglied eines agile...
# 9   International agieren: Du setzt nationale und ...
# 10  Vernetzt arbeiten: Als Schnittstelle zu Stakeh...
# 11  Dies ist eine Anzeige von IThanse.de des Empfe...
# 12  Schlagworte: ecommerce, Beschaffung, B2B, Unit...]
#                                                   job  \
# 0                                Data Analyst (w/m/d)
# 1                          Data Analyst Visualisation
# 2                               Data Engineer (m/w/d)
# 3                      Data Engineer (m/w/d) 154-6139
# 4                                      Data Scientist
# 5          Data Scientist Infektionsforschung (w/m/d)
# 6      Data Analyst - Customer Relations / IT (m/w/d)
# 7                              Data Scientist (m/w/d)
# 8     WEB ANALYST / DATA SCIENTIST E-COMMERCE (M/W/D)
# 9                             Data Scientist (m/w/d)
# 10                             Data Scientist (w/m/d)
# 11                     Specialist Master Data (m/w/d)
# 12                            Data Scientist (w/m/d)
# 13  Datenbankspezialist Data Scientist/Data Analys...
# 14  19652: IT Projekt Manager (m/w/d) - Data Analy...
# 15  Portfoliomanager (m/w/d) mit Schwerpunkt Data ...
# 16                      (Senior) Data Analyst (w/m/d)
# 17  Wissenschaftliche/r Mitarbeiter Datenanlyse (m...
# 18  Berater Business Intelligence (m/w/d) – (Data ...
# 19  Business Analyst / Data Scientist Sales / Mark...
# 20                      SENIOR DATA SCIENTIST (M/W/D)
# 21  Head of Software: Softwareentwickler/Informati...
# 22                             Data Scientist (m/w/d)
# 23  Data Scientist Process Intelligence (m/w/d) fü...
# 24  Data Scientist, Schatzsucher und Managementber...
# 25                             Data Scientist (m/w/d)
# 26      Data Scientist (m/w/d) Simulation Engineering
# 27                             DATA SCIENTIST (m/f/d)
# 28                             Data Scientist (m/w/d)
# 29           Senior Data Scientist (w/m/d) in Hamburg
# 30                      (Senior) Data Scientist (wmd)
# 31                             Senior Data Scientist
# 32  Vertriebscontroller / Data Scientist (m/w/d) |...
#
#                                     company  \
# 0               Brunel GmbH NL Braunschweig
# 1   direct services Gütersloh GmbH – BPG IT
# 2                           alexander thamm
# 3                         top itservices AG
# 4                                  Bayer AG
# 5                               Brunel GmbH
# 6                          Campusjäger GmbH
# 7                            dotSource GmbH
# 8                                     Falke
# 9                                   Ferchau
# 10                        Handelsblatt GmbH
# 11                       König GmbH & Co KG
# 12                 Schwarz Produktions GmbH
# 13                                Grinnberg
# 14                    Cs2 ITEC GmbH & Co.KG
# 15                             Südweststrom
# 16                                 Lunapark
# 17                        Bundeskriminalamt
# 18                              initions AG
# 19                           Mediatech GmbH
# 20             AIM Agile IT Management GmbH
# 21                               AITAD GmbH
# 22                              IKK Südwest
# 23                              Symate GmbH
# 24                               CTcon GmbH
# 25           Schickler Unternehmensberatung
# 26                              Synaos GmbH
# 27                  Westphalia DataLap GmbH
# 28                       WidasConcepts GmbH
# 29                          adesso IT Hanse
# 30                                adesso SE
# 31                              Carrypicker
# 32                          Mercateo Gruppe
#
#                                           description language
# 0   Stellenbeschreibung Möchten Sie die nächste St...       de
# 1   Data Analyst Visualisation Die BPG-IT gehört z...       de
# 2   Festanstellung, Vollzeit · an allen Standorten...       de
# 3   Stellenbeschreibung Sie suchen einen Arbeitgeb...       de
# 4   Stellenbeschreibung Bayer ist ein weltweit tät...       de
# 5   Stellenbeschreibung Sie suchen eine neue Herau...       de
# 6   Aufgaben Was erwartet dich? Du unterstützt das...       de
# 7   Stellenbeschreibung Data Scientist (m/w/d) dot...       de
# 8   EINE HERAUSFORDERUNG MIT AN­ZIE­HUNGS­KRAFT: A...       de
# 9   Stellenbeschreibung Sie sind bereit für eine n...       de
# 10  Deine Aufgaben: Konzeption und Durchführung vo...       de
# 11  Verstärken Sie unser Team! Zur unbefristeten F...       de
# 12  Vertragsart: Unbefristet Zu besetzen: ab sofor...       de
# 13   - Raum Wiesbaden - Datenbanken - Data Experto...       de
# 14  Stellenbeschreibung Cs2 ITEC bietet Ihnen als ...       de
# 15  Ihre Aufgaben: Analyse und Bewirtschaftung der...       de
# 16  DAS BRINGST DU IDEALERWEISE MIT: Du liebst und...       de
# 17  Stellenbeschreibung Wissenschaftliche Mitarbei...       de
# 18  Zur Verstärkung unseres Teams am Standort Hamb...       de
# 19  Table.Media ist ein Teil der Trafo.Gruppe. Wir...       de
# 20  Als Senior Data Scientist (m/w/d) realisierst ...       de
# 21  Deine Aufgaben: Organisation/Teamleitung vom i...       de
# 22  Was dürfen Sie erwarten? eine Zielvergütung na...       de
# 23  Gestalte mit uns den Bereich der KI-gestützten...       de
# 24  Das Profil mag ungewöhnlich erscheinen. Das An...       de
# 25  Als Data Scientist bist Du Teil unseres SCHICK...       de
# 26  SYNAOS ist ein 2018 gegründetes Software-Start...       de
# 27  DEIN UMFELD UND TEAM Du glaubst an die Kraft v...       de
# 28  Die Widas Technologie Services ist ein global ...       de
# 29  Wir gehören zu den Top-Adressen in der IT-Welt...       de
# 30  Deine Rolle - das wartet auf Dich Gestalte gem...       de
# 31  Aufgaben Du nutzt neueste Methoden aus dem Umf...       de
# 32  Die Mercateo Gruppe stellt als Betreiber von B...       de
